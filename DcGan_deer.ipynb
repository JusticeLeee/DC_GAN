# %% [markdown]
# # 需要的函數

# %%
import numpy as np
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # 加載數據

# %%
# 加載數據
def load_cfar10_batch(cifar10_dataset_folder_path, batch_id):
    """
    cifar10_dataset_folder_path: 數據要存的目錄
    batch_id: 指定batch的編號
    """
    with open(cifar10_dataset_folder_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')
    
    # features and labels
    features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    labels = batch['labels']

    return features, labels

# %%
import tarfile
cifar10_path = 'cifar-10-batches-py'
tar_gz_path = 'cifar-10-python.tar.gz'
with tarfile.open(tar_gz_path) as tar:
    tar.extractall()
    tar.close()

# 有5個batch的訓練數量
x_train, y_train = load_cfar10_batch(cifar10_path, 1)
for i in range(2, 6):
    features, labels = load_cfar10_batch(cifar10_path, i)
    x_train, y_train = np.concatenate([x_train, features]), np.concatenate([y_train, labels])

# %%
# 顯示圖片
fig, axes = plt.subplots(nrows=3, ncols=20, sharex=True, sharey=True, figsize=(80,12))
imgs = x_train[:60]
for image, row in zip([imgs[:60], imgs[20:40], imgs[40:60]], axes):
    for img, ax in zip(image, row):
        ax.imshow(img)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)

# %% [markdown]
# # 對數據做預處理

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

#reshape
x_train_rows = x_train.reshape(x_train.shape[0], 32 * 32 * 3)
x_train = minmax.fit_transform(x_train_rows)

# %%
# 重新变为32 x 32 x 3
x_train = x_train.reshape(x_train.shape[0], 32, 32, 3)

# %%
# 鹿的圖片在第四張
images = x_train[y_train==4]

# %% [markdown]
# # model架構
#
# - inputs
# - generator
# - discriminator
# - loss
# - optimizer
# - train

# %% [markdown]
# ## Inputs

# %%
def get_inputs(noise_dim, image_height, image_width, image_depth):
    """
    noise_dim: 噪聲圖片的size
    image_height: 真實圖像的height
    image_width: 真實圖像的width
    image_depth: 真實圖像的depth
    """
    inputs_real = tf.placeholder(tf.float32, [None, image_height, image_width, image_depth], name='inputs_real')
    inputs_noise = tf.placeholder(tf.float32, [None, noise_dim], name='inputs_noise')
    
    return inputs_real, inputs_noise

# %% [markdown]
# # Generator

# %%
def get_generator(noise_img, output_dim, is_train=True, alpha=0.01):
    """
    noise_img: 噪聲圖片
    output_dim: 生成圖片的depth
    is_train: 是否為訓練狀態
    alpha: Leaky ReLU係數
    """
    
    with tf.variable_scope("generator", reuse=(not is_train)):
        # 100 x 1 to 4 x 4 x 512
        # 全連接層
        layer1 = tf.layers.dense(noise_img, 4*4*512)
        layer1 = tf.reshape(layer1, [-1, 4, 4, 512])
        # batch normalization
        layer1 = tf.layers.batch_normalization(layer1, training=is_train)
        # Leaky ReLU
        layer1 = tf.maximum(alpha * layer1, layer1)
        # dropout
        layer1 = tf.nn.dropout(layer1, keep_prob=0.8)
        
        # 4 x 4 x 512 to 8 x 8 x 256
        layer2 = tf.layers.conv2d_transpose(layer1, 256, 4, strides=2, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=is_train)
        layer2 = tf.maximum(alpha * layer2, layer2)
        layer2 = tf.nn.dropout(layer2, keep_prob=0.8)
        
        # 8 x 8 256 to 16 x 16 x 128
        layer3 = tf.layers.conv2d_transpose(layer2, 128, 3, strides=2, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=is_train)
        layer3 = tf.maximum(alpha * layer3, layer3)
        layer3 = tf.nn.dropout(layer3, keep_prob=0.8)
        
        # 16 x 16 x 128 to 32 x 32 x 3
        logits = tf.layers.conv2d_transpose(layer3, output_dim, 3, strides=2, padding='same')
        outputs = tf.tanh(logits)
        
        return outputs

# %% [markdown]
# ## Discriminator

# %%
def get_discriminator(inputs_img, reuse=False, alpha=0.01):
    """
    inputs_img: 輸入圖片
    alpha: Leaky ReLU係數
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # 32 x 32 x 3 to 16 x 16 x 128
        # 第一層不加入BN
        layer1 = tf.layers.conv2d(inputs_img, 128, 3, strides=2, padding='same')
        layer1 = tf.maximum(alpha * layer1, layer1)
        layer1 = tf.nn.dropout(layer1, keep_prob=0.8)
        
        # 16 x 16 x 128 to 8 x 8 x 256
        layer2 = tf.layers.conv2d(layer1, 256, 3, strides=2, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=True)
        layer2 = tf.maximum(alpha * layer2, layer2)
        layer2 = tf.nn.dropout(layer2, keep_prob=0.8)
        
        # 8 x 8 x 256 to 4 x 4 x 512
        layer3 = tf.layers.conv2d(layer2, 512, 3, strides=2, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=True)
        layer3 = tf.maximum(alpha * layer3, layer3)
        layer3 = tf.nn.dropout(layer3, keep_prob=0.8)
        
        # 4 x 4 x 512 to 4*4*512 x 1
        flatten = tf.reshape(layer3, (-1, 4*4*512))
        logits = tf.layers.dense(flatten, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %% [markdown]
# ## Loss

# %%
def get_loss(inputs_real, inputs_noise, image_depth, smooth=0.1):
    """
    inputs_real: 輸入圖片，tensor類型
    inputs_noise: 噪聲圖片，tensor類型
    image_depth: 圖片的depth（或者叫channel）
    smooth: label smoothing的參數
    """
    
    g_outputs = get_generator(inputs_noise, image_depth, is_train=True)
    d_logits_real, d_outputs_real = get_discriminator(inputs_real)
    d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, reuse=True)
    
    # 計算Loss
    g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                    labels=tf.ones_like(d_outputs_fake)*(1-smooth)))
    
    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real,
                                                                         labels=tf.ones_like(d_outputs_real)*(1-smooth)))
    d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                         labels=tf.zeros_like(d_outputs_fake)))
    d_loss = tf.add(d_loss_real, d_loss_fake)
    
    return g_loss, d_loss

# %% [markdown]
# ## Optimizer

# %%
def get_optimizer(g_loss, d_loss, beta1=0.4, learning_rate=0.001):
    """
    g_loss: Generator的Loss
    d_loss: Discriminator的Loss
    learning_rate: 學習率
    """
    
    train_vars = tf.trainable_variables()
    
    g_vars = [var for var in train_vars if var.name.startswith("generator")]
    d_vars = [var for var in train_vars if var.name.startswith("discriminator")]
    
    # Optimizer
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        g_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
        d_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    
    return g_opt, d_opt

# %% [markdown]
# ## 顯示迭代過程中圖片的函數

# %%
def plot_images(samples):
    samples = (samples + 1) / 2
    fig, axes = plt.subplots(nrows=1, ncols=15, sharex=True, sharey=True, figsize=(30,2))
    for img, ax in zip(samples, axes):
        ax.imshow(img.reshape((32, 32, 3)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    fig.tight_layout(pad=0)

# %%
def show_generator_output(sess, n_images, inputs_noise, output_dim):
    """
    sess: TensorFlow session
    n_images: 展示圖片的數量
    inputs_noise: 噪聲圖片
    output_dim: 圖片的depth
    image_mode: 圖像模式
    """
    cmap = 'Greys_r'
    noise_shape = inputs_noise.get_shape().as_list()[-1]
    # 生成噪聲圖片
    examples_noise = np.random.uniform(-1, 1, size=[n_images, noise_shape])

    samples = sess.run(get_generator(inputs_noise, output_dim, False),
                       feed_dict={inputs_noise: examples_noise})
    return samples

# %% [markdown]
# ## Train

# %%
# 定義參數
batch_size = 64
noise_size = 100
epochs = 50
n_samples = 15
learning_rate = 0.001
beta1 = 0.4

# %%
def train(noise_size, data_shape, batch_size, n_samples):
    """
    noise_size: 噪聲size
    data_shape: 真實圖像shape
    batch_size: batch的大小
    n_samples: 圖片數量
    """
    
    # 存儲loss
    losses = []
    steps = 0
    
    inputs_real, inputs_noise = get_inputs(noise_size, data_shape[1], data_shape[2], data_shape[3])
    g_loss, d_loss = get_loss(inputs_real, inputs_noise, data_shape[-1])
    g_train_opt, d_train_opt = get_optimizer(g_loss, d_loss, beta1, learning_rate)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        # 迭代epoch
        for e in range(epochs):
            for batch_i in range(images.shape[0]//batch_size-1):
                steps += 1
                batch_images = images[batch_i * batch_size: (batch_i+1)*batch_size]

                # scale to -1, 1
                batch_images = batch_images * 2 - 1

                # noise
                batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))

                # run optimizer
                _ = sess.run(g_train_opt, feed_dict={inputs_real: batch_images,
                                                     inputs_noise: batch_noise})
                _ = sess.run(d_train_opt, feed_dict={inputs_real: batch_images,
                                                     inputs_noise: batch_noise})
                
                if steps % 100 == 0:
                    train_loss_d = d_loss.eval({inputs_real: batch_images,
                                                inputs_noise: batch_noise})
                    train_loss_g = g_loss.eval({inputs_real: batch_images,
                                                inputs_noise: batch_noise})
                    losses.append((train_loss_d, train_loss_g))
                    # 顯示圖片
                    samples = show_generator_output(sess, n_samples, inputs_noise, data_shape[-1])
                    plot_images(samples)
                    print("Epoch {}/{}....".format(e+1, epochs),
                          "Discriminator Loss: {:.4f}....".format(train_loss_d),
                          "Generator Loss: {:.4f}....". format(train_loss_g))

# %%
with tf.Graph().as_default():
    train(noise_size, [-1, 32, 32, 3], batch_size, n_samples)
# Out:
# Epoch 2/50.... Discriminator Loss: 0.7783.... Generator Loss: 4.6263....
# Epoch 3/50.... Discriminator Loss: 0.8670.... Generator Loss: 1.3040....
# Epoch 4/50.... Discriminator Loss: 0.5221.... Generator Loss: 2.7065....
# Epoch 6/50.... Discriminator Loss: 0.6471.... Generator Loss: 1.9202....
# Epoch 7/50.... Discriminator Loss: 0.9764.... Generator Loss: 3.0730....
# Epoch 8/50.... Discriminator Loss: 0.9058.... Generator Loss: 1.6168....
# Epoch 10/50.... Discriminator Loss: 0.5591.... Generator Loss: 2.0334....
# Epoch 11/50.... Discriminator Loss: 0.7577.... Generator Loss: 1.5683....
# Epoch 12/50.... Discriminator Loss: 0.8957.... Generator Loss: 1.3390....
# Epoch 13/50.... Discriminator Loss: 0.6243.... Generator Loss: 1.7028....
# Epoch 15/50.... Discriminator Loss: 0.7006.... Generator Loss: 1.6806....
# Epoch 16/50.... Discriminator Loss: 1.3895.... Generator Loss: 2.7652....
# Epoch 17/50.... Discriminator Loss: 0.7660.... Generator Loss: 2.2594....
# Epoch 19/50.... Discriminator Loss: 0.7147.... Generator Loss: 1.7516....
# Epoch 20/50.... Discriminator Loss: 0.9555.... Generator Loss: 1.0040....
# Epoch 21/50.... Discriminator Loss: 0.7165.... Generator Loss: 2.2114....
# Epoch 23/50.... Discriminator Loss: 1.1539.... Generator Loss: 2.7523....
# Epoch 24/50.... Discriminator Loss: 1.0855.... Generator Loss: 3.0138....
# Epoch 25/50.... Discriminator Loss: 0.8165.... Generator Loss: 2.7662....
# Epoch 26/50.... Discriminator Loss: 0.5963.... Generator Loss: 1.6923....
# Epoch 28/50.... Discriminator Loss: 0.7618.... Generator Loss: 1.3297....
# Epoch 29/50.... Discriminator Loss: 0.8851.... Generator Loss: 1.1169....
# Epoch 30/50.... Discriminator Loss: 0.6448.... Generator Loss: 1.6921....
# Epoch 32/50.... Discriminator Loss: 1.0900.... Generator Loss: 0.9100....
# Epoch 33/50.... Discriminator Loss: 0.7685.... Generator Loss: 1.2842....
# Epoch 34/50.... Discriminator Loss: 0.4826.... Generator Loss: 2.8322....
# Epoch 36/50.... Discriminator Loss: 0.9834.... Generator Loss: 1.0049....
# Epoch 37/50.... Discriminator Loss: 0.4777.... Generator Loss: 2.4691....
# Epoch 38/50.... Discriminator Loss: 0.6235.... Generator Loss: 4.5382....
# Epoch 39/50.... Discriminator Loss: 0.8257.... Generator Loss: 2.4529....
# Epoch 41/50.... Discriminator Loss: 0.6867.... Generator Loss: 1.4538....
# Epoch 42/50.... Discriminator Loss: 0.5357.... Generator Loss: 2.6744....
# Epoch 43/50.... Discriminator Loss: 0.7560.... Generator Loss: 1.5606....
# Epoch 45/50.... Discriminator Loss: 0.5463.... Generator Loss: 2.3012....
# Epoch 46/50.... Discriminator Loss: 0.5147.... Generator Loss: 3.3334....
# Epoch 47/50.... Discriminator Loss: 0.4651.... Generator Loss: 2.9461....
# Epoch 49/50.... Discriminator Loss: 0.9488.... Generator Loss: 3.0029....
# Epoch 50/50.... Discriminator Loss: 0.3953.... Generator Loss: 3.9077....
